# %% [markdown]
# # Hands on Introduction Data Visualization in Python

# %% [markdown]
# ## By Johannes Simatupang M.Kom.,COBIT5 (Feb 2024)

# %% [markdown]
# COMP6577 - Machine Learning >>> Bina Nusantara University

# %% [markdown]
# Source : https://www.geeksforgeeks.org/data-visualization-with-python/

# %%
#Load a comma separated file (CSV file) into a DataFrame:
import pandas as pd

df = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/tips.csv")

display(df.head(10))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %% [markdown]
# # Scatter plot using matplotlib

# %% [raw]
# Scatter plots are used to observe relationships between variables
# and uses dots to represent the relationship between them.

# %%
import matplotlib.pyplot as plt
 
# Scatter plot with day against tip
plt.scatter(df['day'], df['tip'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('Day')
plt.ylabel('Tip')
 
plt.show()

# %%
# Scatter plot with day against tip
plt.scatter(df['day'], df['tip'], c=df['size'], 
            s=df['total_bill'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('Day')
plt.ylabel('Tip')
 
plt.colorbar()

# %% [raw]
# #Exercise 1
# Using dataset from "https://media.geeksforgeeks.org/wp-content/uploads/nba.csv"
# Do Scatter plot with Age against Salary !!!
# python command > ...................

# %% [raw]
# Line Chart is used to represent a relationship between two data X and Y on a different axis

# %%
# Line Chart with day against tip
plt.plot(df['tip'])
plt.plot(df['day'])
 
# Adding Title to the Plot
plt.title("Line Chart")
 
# Setting the X and Y labels
plt.xlabel('Day')
plt.ylabel('Tip')
 
plt.show()

# %% [raw]
# #Exercise 2
# Using dataset from "https://media.geeksforgeeks.org/wp-content/uploads/nba.csv"
# Do Line Chart plot with Position against Salary !!!
# python command > ...................

# %% [raw]
# bar chart is a graph that represents the category of data with rectangular bars with lengths and heights that is proportional to the values which they represent

# %%
# Bar chart with day against tip
plt.bar(df['day'], df['tip'])
 
plt.title("Bar Chart")
 
# Setting the X and Y labels
plt.xlabel('Day')
plt.ylabel('Tip')

# Adding the legends
plt.show()

# %% [raw]
# #Exercise 3
# Using dataset from "https://media.geeksforgeeks.org/wp-content/uploads/nba.csv"
# Do Bar Chart plot with College against Salary !!!
# python command > ...................

# %% [raw]
# A histogram is basically used to represent data in the form of some groups. It is a type of bar plot where the X-axis represents the bin ranges while the Y-axis gives information about frequency.

# %%
# histogram of total_bills
plt.hist(df['total_bill'])
 
plt.title("Histogram")
# Setting the X and Y labels
plt.ylabel('USD Amount')
plt.xlabel('Total Bill') 
# Adding the legends
plt.show()

# %%
# create histogram for numeric data
df.hist()
 
# show plot
plt.show()

# %% [raw]
# #Exercise 4
# Using dataset from "https://media.geeksforgeeks.org/wp-content/uploads/nba.csv"
# Create Histogram !!!
# python command > ...................

# %% [markdown]
# # End Of Practice
